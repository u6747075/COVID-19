# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import statistics as st
from datetime import datetime

# %%
data = pd.read_csv("csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv")
display(data)
# Out:
#     Province/State  Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0              NaN        Thailand  15.0000  101.0000        2        3
# 1              NaN           Japan  36.0000  138.0000        2        1
# 2              NaN       Singapore   1.2833  103.8333        0        1
# 3              NaN           Nepal  28.1667   84.2500        0        0
# 4              NaN        Malaysia   2.5000  112.5000        0        0
# ..             ...             ...      ...       ...      ...      ...
# 457          Aruba     Netherlands  12.5186  -70.0358        0        0
# 458            NaN          Zambia -15.4167   28.2833        0        0
# 459            NaN        Djibouti  11.8251   42.5903        0        0
# 460            NaN     Gambia, The  13.4432  -15.3101        0        0
# 461     Montserrat  United Kingdom  16.7425  -62.1874        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/9/20  3/10/20  3/11/20  \
# ...

# %%
japan = data[data["Country/Region"] == "Japan"]
#display(japan)
time_ser = japan.iloc[:,4:]
#display(list(time_ser.iloc[0]))
fig, ax = plt.subplots()
fig.canvas.draw()
col = time_ser.iloc[0]
dates=list(time_ser)
date_object = datetime.strptime(dates[0], '%m/%d/%y')
x_values = [datetime.strptime(str(d),"%m/%d/%y").date() for d in dates]

plt.plot(x_values,list(col), c = "red")

ax.set_xticklabels(x_values, rotation=45)
plt.tight_layout()

plt.show()
plt.savefig("Users\Mahir\OneDrive\3_18_20_japan.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-124-da75ec0ac8aa> in <module>
#      16
#      17 plt.show()
# ---> 18 plt.savefig("Users\Mahir\OneDrive\3_18_20_japan.png")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# --> 729     res = fig.savefig(*args, **kwargs)
#     730     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     731     return res
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ...
