# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import statistics as st
from datetime import datetime

# %%
data = pd.read_csv("csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv")
display(data)
# Out:
#             Province/State Country/Region      Lat      Long  1/22/20  \
# 0                      NaN       Thailand  15.0000  101.0000        2
# 1                      NaN          Japan  36.0000  138.0000        2
# 2                      NaN      Singapore   1.2833  103.8333        0
# 3                      NaN          Nepal  28.1667   84.2500        0
# 4                      NaN       Malaysia   2.5000  112.5000        0
# ..                     ...            ...      ...       ...      ...
# 477  Northwest Territories         Canada  64.8255 -124.8457        0
# 478                    NaN     Cape Verde  15.1111  -23.6167        0
# 479                    NaN     East Timor  -8.5500  125.5600        0
# 480                    NaN        Eritrea  15.1794   39.7823        0
# 481                    NaN         Uganda   1.0000   32.0000        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/12/20  3/13/20  \
# 0          3        5        7        8        8  ...       70       75
# 1          1        2        2        4        4  ...      639      701
# 2          1        3        3        4        5  ...      178      200
# 3          0        0        1        1        1  ...        1        1
# 4          0        0        3        4        4  ...      149      197
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 477        0        0        0        0        0  ...        0        0
# 478        0        0        0        0        0  ...        0        0
# 479        0        0        0        0        0  ...        0        0
# 480        0        0        0        0        0  ...        0        0
# 481        0        0        0        0        0  ...        0        0
#
#      3/14/20  3/15/20  3/16/20  3/17/20  3/18/20  3/19/20  3/20/20  3/21/20
# 0         82      114      147      177      212      272      322      411
# 1        773      839      825      878      889      924      963     1007
# 2        212      226      243      266      313      345      385      432
# 3          1        1        1        1        1        1        1        1
# 4        238      428      566      673      790      900     1030     1183
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 477        0        0        0        0        0        0        0        1
# 478        0        0        0        0        0        0        0        1
# 479        0        0        0        0        0        0        0        1
# 480        0        0        0        0        0        0        0        1
# 481        0        0        0        0        0        0        0        1
#
# [482 rows x 64 columns]

# %%
japan = data[data["Country/Region"] == "Japan "]
#display(japan)
time_ser = japan.iloc[:,4:]
#display(list(time_ser.iloc[0]))
fig, ax = plt.subplots()
fig.canvas.draw()
col = time_ser.iloc[0]
dates=list(time_ser)
date_object = datetime.strptime(dates[0], '%m/%d/%y')
x_values = [datetime.strptime(str(d),"%m/%d/%y").date() for d in dates]

plt.plot(x_values,list(col), c = "red")

ax.set_xticklabels(x_values, rotation=45)
plt.tight_layout()

plt.show()

# %%
da = pd.read_csv("csse_covid_19_data/csse_covid_19_daily_reports/03-21-2020.csv")
au = da[da["Country/Region"] == "Australia"]
display(au)
T_R=sum(list(da["Recovered"]))
T_D=sum(list(da["Deaths"]))
T_C=sum(list(da["Confirmed"]))
AU_R=sum(list(au["Recovered"]))
AU_D=sum(list(au["Deaths"]))
AU_C=sum(list(au["Confirmed"]))
print("Confirmed in AU: ",sum(list(au["Confirmed"])))
print("Recovered in AU: ",sum(list(au["Recovered"])))
print("Deaths in AU:    ",sum(list(au["Deaths"])))
print("Total Confirmed: ",sum(list(da["Confirmed"])))
print("Total Recovered: ",sum(list(da["Recovered"])))
print("Total Deaths:    ",sum(list(da["Deaths"])))
print("Recover Rate:    ",np.round(T_R*100/T_C,3),"%")
print("Deaths Rate:     ",np.round(T_D*100/T_C,3),"%")
print("AU Recover Rate: ",np.round(AU_R*100/AU_C,3),"%")
print("AU Deaths Rate:  ",np.round(AU_D*100/AU_C,3),"%")
# Out:
#                    Province/State Country/Region          Last Update  \
# 57                New South Wales      Australia  2020-03-21T13:13:35
# 85                       Victoria      Australia  2020-03-21T13:13:35
# 86                     Queensland      Australia  2020-03-21T13:13:35
# 135             Western Australia      Australia  2020-03-21T13:13:35
# 156               South Australia      Australia  2020-03-21T13:13:35
# 209                      Tasmania      Australia  2020-03-21T13:13:35
# 225  Australian Capital Territory      Australia  2020-03-21T13:13:35
# 243            Northern Territory      Australia  2020-03-20T21:13:29
# 291         From Diamond Princess      Australia  2020-03-14T02:33:04
#
#      Confirmed  Deaths  Recovered  Latitude  Longitude
# 57         436       6          4  -33.8688   151.2093
# 85         229       0          8  -37.8136   144.9631
# 86         221       0          8  -28.0167   153.4000
# 135         90       1          0  -31.9505   115.8605
# 156         67       0          3  -34.9285   138.6007
# 209         16       0          3  -41.4545   145.9707
# 225          9       0          0  -35.4735   149.0124
# 243          3       0          0  -12.4634   130.8456
# 291          0       0          0   35.4437   139.6380
# Confirmed in AU:  1071
# Recovered in AU:  26
# Deaths in AU:     7
# Total Confirmed:  304528
# Total Recovered:  91676
# Total Deaths:     12973
# Recover Rate:     30.104 %
# Deaths Rate:      4.26 %
# AU Recover Rate:  2.428 %
# AU Deaths Rate:   0.654 %
