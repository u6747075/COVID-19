# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import statistics as st
from sklearn.linear_model import LinearRegression
from datetime import datetime

# %%
data = pd.read_csv("csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")
display(data)
# Out:
#                   Province/State         Country/Region       Lat       Long  \
# 0                            NaN            Afghanistan  33.00000  65.000000
# 1                            NaN                Albania  41.15330  20.168300
# 2                            NaN                Algeria  28.03390   1.659600
# 3                            NaN                Andorra  42.50630   1.521800
# 4                            NaN                 Angola -11.20270  17.873900
# ..                           ...                    ...       ...        ...
# 258  Falkland Islands (Malvinas)         United Kingdom -51.79630 -59.523600
# 259    Saint Pierre and Miquelon                 France  46.88520 -56.315900
# 260                          NaN            South Sudan   6.87700  31.307000
# 261                          NaN         Western Sahara  24.21550 -12.885800
# 262                          NaN  Sao Tome and Principe   0.18636   6.613081
#
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/30/20  \
# 0          0        0        0        0        0        0  ...      170
# 1          0        0        0        0        0        0  ...      223
# 2          0        0        0        0        0        0  ...      584
# 3          0        0        0        0        0        0  ...      370
# 4          0        0        0        0        0        0  ...        7
# ..       ...      ...      ...      ...      ...      ...  ...      ...
# 258        0        0        0        0        0        0  ...        0
# 259        0        0        0        0        0        0  ...        0
# 260        0        0        0        0        0        0  ...        0
# 261        0        0        0        0        0        0  ...        0
# 262        0        0        0        0        0        0  ...        0
#
#      3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20  4/6/20  4/7/20  4/8/20
# 0        174     237     273     281     299     349     367     423     444
# 1        243     259     277     304     333     361     377     383     400
# 2        716     847     986    1171    1251    1320    1423    1468    1572
# 3        376     390     428     439     466     501     525     545     564
# 4          7       8       8       8      10      14      16      17      19
# ..       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 258        0       0       0       0       1       2       2       2       5
# 259        0       0       0       0       0       1       1       1       1
# 260        0       0       0       0       0       1       1       2       2
# 261        0       0       0       0       0       4       4       4       4
# 262        0       0       0       0       0       0       4       4       4
#
# [263 rows x 82 columns]

# %%
japan = data[data["Country/Region"] == "Japan"]
display(japan)
time_ser = japan.iloc[:,4:]
#display(list(time_ser.iloc[0]))
fig, ax = plt.subplots()
fig.canvas.draw()
col = time_ser.iloc[0]
dates=list(time_ser)
date_object = datetime.strptime(dates[0], '%m/%d/%y')
x_values = [datetime.strptime(str(d),"%m/%d/%y").date() for d in dates]

plt.plot(dates, col, c = "red")

ax.set_xticklabels(x_values, rotation=45)
plt.tight_layout()

plt.show()
# Out:
#     Province/State Country/Region   Lat   Long  1/22/20  1/23/20  1/24/20  \
# 139            NaN          Japan  36.0  138.0        2        2        2
#
#      1/25/20  1/26/20  1/27/20  ...  3/30/20  3/31/20  4/1/20  4/2/20  4/3/20  \
# 139        2        4        4  ...     1866     1953    2178    2495    2617
#
#      4/4/20  4/5/20  4/6/20  4/7/20  4/8/20
# 139    3139    3139    3654    3906    4257
#
# [1 rows x 82 columns]

# %%
da = pd.read_csv("csse_covid_19_data/csse_covid_19_daily_reports/04-08-2020.csv")
au = da[da["Country_Region"] == "Australia"]
display(au)
T_R=sum(list(da["Recovered"]))
T_D=sum(list(da["Deaths"]))
T_C=sum(list(da["Confirmed"]))
AU_R=sum(list(au["Recovered"]))
AU_D=sum(list(au["Deaths"]))
AU_C=sum(list(au["Confirmed"]))
print("Confirmed in AU: ",sum(list(au["Confirmed"])))
print("Recovered in AU: ",sum(list(au["Recovered"])))
print("Deaths in AU:    ",sum(list(au["Deaths"])))
print("Total Confirmed: ",sum(list(da["Confirmed"])))
print("Total Recovered: ",sum(list(da["Recovered"])))
print("Total Deaths:    ",sum(list(da["Deaths"])))
print("Total Active:    ",sum(list(da["Active"])))
print("Recover Rate:    ",np.round(T_R*100/T_C,3),"%")
print("Deaths Rate:     ",np.round(T_D*100/T_C,3),"%")
print("AU Recover Rate: ",np.round(AU_R*100/AU_C,3),"%")
print("AU Deaths Rate:  ",np.round(AU_D*100/AU_C,3),"%")
# Out:
#       FIPS Admin2                Province_State Country_Region  \
# 2618   NaN    NaN  Australian Capital Territory      Australia
# 2665   NaN    NaN               New South Wales      Australia
# 2669   NaN    NaN            Northern Territory      Australia
# 2677   NaN    NaN                    Queensland      Australia
# 2690   NaN    NaN               South Australia      Australia
# 2692   NaN    NaN                      Tasmania      Australia
# 2696   NaN    NaN                      Victoria      Australia
# 2698   NaN    NaN             Western Australia      Australia
#
#               Last_Update      Lat     Long_  Confirmed  Deaths  Recovered  \
# 2618  2020-04-08 22:59:00 -35.4735  149.0124         99       2         40
# 2665  2020-04-08 22:59:00 -33.8688  151.2093       2734      21          4
# 2669  2020-04-08 22:59:00 -12.4634  130.8456         28       0          2
# 2677  2020-04-08 22:59:00 -27.4698  153.0251        943       4        173
# 2690  2020-04-08 22:59:00 -34.9285  138.6007        415       2         53
# 2692  2020-04-08 22:59:00 -42.8821  147.3272         98       3         26
# 2696  2020-04-08 22:59:00 -37.8136  144.9631       1212      12        620
# 2698  2020-04-08 22:59:00 -31.9505  115.8605        481       6        162
#
#       Active                             Combined_Key
# 2618      57  Australian Capital Territory, Australia
# 2665    2709               New South Wales, Australia
# 2669      26            Northern Territory, Australia
# 2677     766                    Queensland, Australia
# 2690     360               South Australia, Australia
# 2692      69                      Tasmania, Australia
# 2696     580                      Victoria, Australia
# 2698     313             Western Australia, Australia
# Confirmed in AU:  6010
# Recovered in AU:  1080
# Deaths in AU:     50
# Total Confirmed:  1511104
# Total Recovered:  328661
# Total Deaths:     88338
# Total Active:     688727
# Recover Rate:     21.75 %
# Deaths Rate:      5.846 %
# AU Recover Rate:  17.97 %
# AU Deaths Rate:   0.832 %
